# %%
from src.data.preprocessing import DataPreprocessor

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from src.data.preprocessing import DataPreprocessor
#       4 from sklearn.feature_extraction.text import TfidfVectorizer
#       5 from sklearn.linear_model import LogisticRegression
#
# ModuleNotFoundError: No module named 'src'

# %%
# Load and preprocess data
file_path = '../data/gender.csv'

preprocessor = DataPreprocessor(df)
train_df, val_df, test_df = preprocessor.get_splits()

# %% [markdown]
# ### Majority Baseline

# %%
majority_class_percentage = (df['female'].value_counts(normalize=True) * 100)[1]
print(f"The majority baseline is: {majority_class_percentage:.2f}%")
# Out:
# The majority baseline is: 46.73%

# %% [markdown]
# ### Simple logistic Regression Baseline

# %%
# Convert text data to TF-IDF features
vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = vectorizer.fit_transform(train_df['post'])
X_val_tfidf = vectorizer.transform(val_df['post'])
X_test_tfidf = vectorizer.transform(test_df['post'])

# Train a logistic regression classifier
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train_tfidf, train_df['female'])

# Evaluate the model
val_predictions = classifier.predict(X_val_tfidf)
test_predictions = classifier.predict(X_test_tfidf)

print("The simple logistic regression with TF-IDF baseline is:")
print("Validation Results:")
print(classification_report(val_df['female'], val_predictions))

print("Test Results:")
print(classification_report(test_df['female'], test_predictions))
# Out:
# The simple logistic regression with TF-IDF baseline is:
# Validation Results:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      3673
#            1       0.86      0.80      0.83      2654
#
#     accuracy                           0.86      6327
#    macro avg       0.86      0.85      0.85      6327
# weighted avg       0.86      0.86      0.86      6327
#
# Test Results:
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81      3691
#            1       0.87      0.73      0.79      4036
#
#     accuracy                           0.80      7727
#    macro avg       0.81      0.81      0.80      7727
# weighted avg       0.81      0.80      0.80      7727

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Step 1: Load the data
file_path = '../data/embedded/embedded_test_data.csv'
data = pd.read_csv(file_path)

# Step 2: Extract the target variable 'female'
y_true = data['female']

# Step 3: Majority baseline prediction (predict the majority class)
majority_class = y_true.mode()[0]  # Find the most frequent class (majority class)
y_pred_majority = [majority_class] * len(y_true)  # Predict the majority class for all instances

# Step 4: Calculate evaluation metrics
accuracy = accuracy_score(y_true, y_pred_majority)
precision = precision_score(y_true, y_pred_majority)
recall = recall_score(y_true, y_pred_majority)
f1 = f1_score(y_true, y_pred_majority)

# Step 5: Print the results
print(f'Majority Baseline Model Evaluation:')
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Majority Baseline Model Evaluation:
# Accuracy: 0.5065
# Precision: 0.5065
# Recall: 1.0000
# F1 Score: 0.6725
