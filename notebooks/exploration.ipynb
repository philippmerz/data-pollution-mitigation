# %%
import pandas as pd

# %%
data = pd.read_csv('../data/gender.csv')
print(data.head())
print(len(data))
# Out:
#     auhtor_ID                                               post  female
# 0  t2_rnjzutp  Good on you for being responsible! I know self...       1
# 1  t2_rnjzutp  must go to the grocery store with their child,...       1
# 2  t2_rnjzutp  things on her videos, and YouTube took the vid...       1
# 3  t2_rnjzutp  their app. There's also a program called SYNC ...       1
# 4  t2_rnjzutp  side. If the cops don't take your side, you'll...       1
# 44635

# %%
def analyze_author_distribution(df):
    # Get post counts per author
    author_counts = df['auhtor_ID'].value_counts()

    # Calculate key statistics
    total_authors = len(author_counts)
    total_posts = author_counts.sum()
    mean_posts = author_counts.mean()
    median_posts = author_counts.median()
    max_posts = author_counts.max()
    min_posts = author_counts.min()

    # Calculate percentiles
    percentiles = author_counts.quantile([0.25, 0.75, 0.9, 0.95, 0.99])

    print(f"Author Post Distribution Statistics:")
    print(f"Total Authors: {total_authors:,}")
    print(f"Total Posts: {total_posts:,}")
    print(f"\nPosts per Author:")
    print(f"Mean: {mean_posts:.1f}")
    print(f"Median: {median_posts:.1f}")
    print(f"Min: {min_posts}")
    print(f"Max: {max_posts}")
    print(f"\nPercentiles:")
    print(f"25th percentile: {percentiles[0.25]:.1f} posts")
    print(f"75th percentile: {percentiles[0.75]:.1f} posts")
    print(f"90th percentile: {percentiles[0.90]:.1f} posts")
    print(f"95th percentile: {percentiles[0.95]:.1f} posts")
    print(f"99th percentile: {percentiles[0.99]:.1f} posts")

    # Calculate proportion of authors with different post counts
    counts_1_5 = sum((author_counts >= 1) & (author_counts <= 5))
    counts_6_20 = sum((author_counts > 5) & (author_counts <= 20))
    counts_21_100 = sum((author_counts > 20) & (author_counts <= 100))
    counts_over_100 = sum(author_counts > 100)

    print(f"\nAuthor Distribution:")
    print(f"Authors with 1-5 posts: {counts_1_5:,} ({counts_1_5/total_authors*100:.1f}%)")
    print(f"Authors with 6-20 posts: {counts_6_20:,} ({counts_6_20/total_authors*100:.1f}%)")
    print(f"Authors with 21-100 posts: {counts_21_100:,} ({counts_21_100/total_authors*100:.1f}%)")
    print(f"Authors with >100 posts: {counts_over_100:,} ({counts_over_100/total_authors*100:.1f}%)")

# %%
analyze_author_distribution(data)
# Out:
# Author Post Distribution Statistics:
# Total Authors: 2,401
# Total Posts: 44,635
#
# Posts per Author:
# Mean: 18.6
# Median: 7.0
# Min: 1
# Max: 525
#
# Percentiles:
# 25th percentile: 3.0 posts
# 75th percentile: 19.0 posts
# 90th percentile: 43.0 posts
# 95th percentile: 69.0 posts
# 99th percentile: 158.0 posts
#
# Author Distribution:
# Authors with 1-5 posts: 1,028 (42.8%)
# Authors with 6-20 posts: 800 (33.3%)
# Authors with 21-100 posts: 507 (21.1%)
# Authors with >100 posts: 66 (2.7%)

# %%
data.loc[19]['post']
# Out:
# 'Mall of The Netherlands near The Hague is an American style mall. It\'s a cool experience. But once the novelty wears off, you can see its just a soulless temple of overconsumption. If I had a car and would need a completely new wardrobe. I might go there. But as it stands now I buy my clothes on my way grocery shopping on my bicycle or after grabbing a bite to eat in quaint cafe in the city centre here. Innovation! I find it kinda funny how you somehow conflate Bangkok with the entirety of Asia (4.5 billion people). Bangkok isn\'t really representative of most of that IMO. Much richer and more modern. That 10% comes from the incorrect assumption that the rest of the village also got rabies. While it is more likely that the 53 others just never got it as they don\'t have antibodies. Ik ga elke keer weer roken als ik een uitlaatklep nodig heb of het mij allemaal iets teveel wordt. Als het goed gaat heb ik wel demotivatie en wil om het niet te doen. Gezien de huidige stand van zaken in de wereld snap ik dat sommige jongeren wat fatalistischer zijn geworden en hiernaar grijpen. Het is ook geen oplossing voor een probleem. Het kan gewoon lekker en gezellig zijn. Bier is vies, in mensen hun bier lucht zitten is niet gezellig. Roken in de auto met kinderen is sinds 2016 terecht verboden. In een kleine, slecht geventileerde ruimte een hoge concentratie rook inademen is zeer slecht. Van een keertje rook ruiken op een terras krijg je geen kanker echter. Measurement is in GJ, the m3 seems to measure the same thing in a different unit for control purposes. url There is a sort of eb and flow of activities here depending on the season. Since you are from a warm country, you might still need to learn to appriciate these new "bad weather activities". The cozyness of sitting on the couch, next to the heater with a cup of tea watching a movie while there is a rainstorm outside. The warm interiors of cafe\'s contrasting with the cold outside. A hot cup of chocolate milk outside with strangers on a snowy day. Or everybody getting together inside to do board game nights and dinner parties. Your metabolism will also adapt to the cold over the span of a month or 2, making you feel less cold. (And you eat more). Summer activities will be back again in spring. I personally kinda like this variety. So we have one of the largest ports in the world and a massive agricultural industry. We have high quality, fresh produce available year round. And you have a cucumber, spinach and some potatoes. +90% processed and pre packaged junk. C\'mon man, you can do better. The main argument is the high level of corruption, not nationality or heritage. Bulgaria and Romania where inducted into the EU before their government was ready just to keep them out of the hands of Russia. Now the EU is using the only stick they have left to retroactively get them to comply to the corruption standards. I don\'t thing the EU would look favorably upon a country just blocking everything out of spite. Giving into that will just cause more cointries to do the same over increasingly petty reasons. &gt;we all know what those reasons are I don\'t? And Croatia isn\'t in Schengen either. &gt;the EU has said multiple times that everything was in order, The EU isn\'t Shengen, just heavily intertwined. Everything isn\'t in order, corruption is rampant. I\'m afraid of that corrupt or otherwise inept governments joining the EU will weaken the EU (Hungary for example). Recruiting Bulgaria and Romania into the EU before they fixed this issue was a necessary evil to ward of Russia. Now that they are in however, we need to fix corruption ASAP. Shengen is used as leverage to get that done. I hope we can somehow get better leverage than Shengen. As this is hurting common folk more than the corrupt individuals. But that\'s another story. No but it is for the EU and that is intertwined with Shengen. Those countries where added to the EU before they fixed corruption to keep them out of the hands of Ru ...

# %%
# Posts seem to be concatenated and then split. Verify this by checking the length counts
post_lengths = data['post'].apply(lambda x: len(x.split()))
post_lengths.value_counts().sort_index()
# Out:
# post
# 269         1
# 271         1
# 272         1
# 275         1
# 276         1
#         ...
# 1495        1
# 1496        1
# 1497        2
# 1499        1
# 1500    42711
# Name: count, Length: 968, dtype: int64
