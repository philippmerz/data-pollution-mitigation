# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
data = pd.read_csv('../data/gender.csv')
print(data.head())
print(len(data))
# Out:
#     auhtor_ID                                               post  female
# 0  t2_rnjzutp  Good on you for being responsible! I know self...       1
# 1  t2_rnjzutp  must go to the grocery store with their child,...       1
# 2  t2_rnjzutp  things on her videos, and YouTube took the vid...       1
# 3  t2_rnjzutp  their app. There's also a program called SYNC ...       1
# 4  t2_rnjzutp  side. If the cops don't take your side, you'll...       1
# 44635

# %%
def analyze_author_distribution(df):
    # Get post counts per author
    author_counts = df['auhtor_ID'].value_counts()

    # Calculate key statistics
    total_authors = len(author_counts)
    total_posts = author_counts.sum()
    mean_posts = author_counts.mean()
    median_posts = author_counts.median()
    max_posts = author_counts.max()
    min_posts = author_counts.min()

    # Calculate percentiles
    percentiles = author_counts.quantile([0.25, 0.75, 0.9, 0.95, 0.99])

    print(f"Author Post Distribution Statistics:")
    print(f"Total Authors: {total_authors:,}")
    print(f"Total Posts: {total_posts:,}")
    print(f"\nPosts per Author:")
    print(f"Mean: {mean_posts:.1f}")
    print(f"Median: {median_posts:.1f}")
    print(f"Min: {min_posts}")
    print(f"Max: {max_posts}")
    print(f"\nPercentiles:")
    print(f"25th percentile: {percentiles[0.25]:.1f} posts")
    print(f"75th percentile: {percentiles[0.75]:.1f} posts")
    print(f"90th percentile: {percentiles[0.90]:.1f} posts")
    print(f"95th percentile: {percentiles[0.95]:.1f} posts")
    print(f"99th percentile: {percentiles[0.99]:.1f} posts")

    # Calculate proportion of authors with different post counts
    counts_1_5 = sum((author_counts >= 1) & (author_counts <= 5))
    counts_6_20 = sum((author_counts > 5) & (author_counts <= 20))
    counts_21_100 = sum((author_counts > 20) & (author_counts <= 100))
    counts_over_100 = sum(author_counts > 100)

    print(f"\nAuthor Distribution:")
    print(f"Authors with 1-5 posts: {counts_1_5:,} ({counts_1_5/total_authors*100:.1f}%)")
    print(f"Authors with 6-20 posts: {counts_6_20:,} ({counts_6_20/total_authors*100:.1f}%)")
    print(f"Authors with 21-100 posts: {counts_21_100:,} ({counts_21_100/total_authors*100:.1f}%)")
    print(f"Authors with >100 posts: {counts_over_100:,} ({counts_over_100/total_authors*100:.1f}%)")

# %%
analyze_author_distribution(data)
# Out:
# Author Post Distribution Statistics:
# Total Authors: 2,401
# Total Posts: 44,635
#
# Posts per Author:
# Mean: 18.6
# Median: 7.0
# Min: 1
# Max: 525
#
# Percentiles:
# 25th percentile: 3.0 posts
# 75th percentile: 19.0 posts
# 90th percentile: 43.0 posts
# 95th percentile: 69.0 posts
# 99th percentile: 158.0 posts
#
# Author Distribution:
# Authors with 1-5 posts: 1,028 (42.8%)
# Authors with 6-20 posts: 800 (33.3%)
# Authors with 21-100 posts: 507 (21.1%)
# Authors with >100 posts: 66 (2.7%)

# %%
data.loc[3]['post']
# Out:
# 'their app. There\'s also a program called SYNC that runs over the summer and lends audiobooks to teenagers to encourage literacy. It\'s entirely 100% free. I was a member back when I was still in high school. Here\'s the link if you\'d like to get her set up on it for the 2023 season: url Consider games as well. It may not seem like people learn much from playing games, but it teaches patience, empathy, and how to be a good sport. I personally like the app Plato because it\'s free and has a lot of off-brand versions of classic games. This would also be a way for you to connect with her while she\'s away. These are just suggestions though, and they aren\'t a good fit for every person. I hope it works out well for all of you. Leave uta no prince sama out of this /joking All Lady D content reminds me of that one song they used in the movie Igor (2008). The Bigger the Figure by Louis Prima. I (21F) just took a driving class last month because I\'m finally getting my license. I\'m getting it later than most people, and that\'s okay. My class was entirely 9th and 10th graders, and that\'s okay. They mostly seemed pretty smart and capable with wood plans for the future, and that\'s okay. What wasn\'t okay is that a lot of the course was watching videos of car crashes and prior who had been involved in crashes taking any why they crashed, what happened, what they could have done differently, bawling their eyes out over their dead loved ones, etc, and every person in the room other than myself and the instructor was playing around on their cell phones. I didn\'t say anything about it because at the end of the day they\'re just kids who don\'t know better, but the absolute lack of empathy and compassion disgusted me. I was appalled. They didn\'t have the decency to set their phones down for just a few minutes to listen to these people\'s stories, and that shocked me. The people who make Facebook memes like this are the reason teens like that are so apathetic and disrespectful. It\'s a situation where they\'re repeating the behavior that they\'re seeing. This meme basically says, "I don\'t like how convenient your life seems to me so I\'m going to give you technology you\'re not familiar with to make your life difficult." That teaches nothing to the person on the receiving end of that except frustration, hostility, and passive aggressiveness. There are healthier ways to limit screen time if that\'s the concern, and there are better ways to teach good values like modeling the behavior you want to see and doing things /with/ someone rather than just telling them to do it. Sorry for ranting, this one just really grinded my gears. I introduced my fiance to LOTR. I don\'t think he really likes it, but he\'ll watch it with me because he loves me and he sends me memes about it even if he doesn\'t understand them because he knows they\'ll make me laugh. He introduced me to Star Wars, and I\'m not super in to it but I\'ll watch it if he\'s got it on because I love him. I send him Star Wars memes even when I don\'t get them because they\'ll probably make him laugh. It\'s an unspoken agreement that we\'re not going to force each other to like a series, and we\'re also not going to force each other to suppress their enjoyment of a series for the other. I dunno, its just nice. I 100% recommend corner guards. I know they\'re not the most aesthetic thing but I can absolutely see you or your clients bumping your shins/knees on that super cute coffee table. My dad was never in the picture, and this is what my fiancé did. My mom even helped him pick out the ring he proposed to me with. It was super sweet &lt;3 We haven\'t set a date yet, but I plan to have my mom walk me down the aisle too. Marnie best girl though It\'s super cute! I like it better with the solid color top for sure. Re2 ada vibes I think it would be a lovely gift. Gnomes are very in-style right now. Thought those were fancy fuzzy sandals until I realized you\'re a hobbit!! I see your poi ...

# %%
# Posts seem to be concatenated and then split. Verify this by checking the length counts
post_lengths = data['post'].apply(lambda x: len(x.split()))
post_lengths.value_counts().sort_index()
# Out:
# post
# 269         1
# 271         1
# 272         1
# 275         1
# 276         1
#         ...
# 1495        1
# 1496        1
# 1497        2
# 1499        1
# 1500    42711
# Name: count, Length: 968, dtype: int64

# %%
# inspect lowest
